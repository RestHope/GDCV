# %% [markdown]
# ## End-to-End OCR

# %% [markdown]
# ###  데이터셋 준비

# %%
import re
import six
import math
import lmdb
import os
import numpy as np
import tensorflow as tf

from PIL import Image

from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.utils import Sequence
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model

BATCH_SIZE = 128
HOME_DIR = os.getenv('HOME')+'/aiffel/cv/g12'

# 로컬 사용자
TRAIN_DATA_PATH = HOME_DIR+'/data/MJ/MJ_train'
VALID_DATA_PATH = HOME_DIR+'/data/MJ/MJ_valid'
TEST_DATA_PATH = HOME_DIR+'/data/MJ/MJ_test'

print(TRAIN_DATA_PATH)
# Out:
# /aiffel/aiffel/cv/g12/data/MJ/MJ_train

# %%
from IPython.display import display

env = lmdb.open(TRAIN_DATA_PATH, max_readers=32, readonly=True, lock=False, readahead=False, meminit=False)
with env.begin(write=False) as txn:
    for index in range(1, 5):
        label_key = 'label-%09d'.encode() % index
        label = txn.get(label_key).decode('utf-8')
        img_key = 'image-%09d'.encode() % index
        imgbuf = txn.get(img_key)
        buf = six.BytesIO()
        buf.write(imgbuf)
        buf.seek(0)
        try:
            img = Image.open(buf).convert('RGB')

        except IOError:
            img = Image.new('RGB', (100, 32))
            label = '-'
        width, height = img.size
        print('original image width:{}, height:{}'.format(width, height))
        
        target_width = min(int(width*32/height), 100)
        target_img_size = (target_width,32 )
        
        print('target_img_size:{}'.format(target_img_size))
        
        img = np.array(img.resize(target_img_size)).transpose(1,0,2)
       
        print('display img shape:{}'.format(img.shape))
        print('label:{}'.format(label))
        display(Image.fromarray(img.transpose(1,0,2).astype(np.uint8)))
# Out:
# original image width:72, height:31
# target_img_size:(74, 32)
# display img shape:(74, 32, 3)
# label:Lube
# <PIL.Image.Image image mode=RGB size=74x32 at 0x7F9B9E18EB50>
# original image width:82, height:31
# target_img_size:(84, 32)
# display img shape:(84, 32, 3)
# label:Spencerian
# <PIL.Image.Image image mode=RGB size=84x32 at 0x7FA1A4465790>
# original image width:115, height:31
# target_img_size:(100, 32)
# display img shape:(100, 32, 3)
# label:accommodatingly
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F9B9E18E050>
# original image width:140, height:31
# target_img_size:(100, 32)
# display img shape:(100, 32, 3)
# label:CARPENTER
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7FA1A4465210>

# %%
class MJDatasetSequence(Sequence):
    def __init__(self, 
                      dataset_path,
                      label_converter,   # 문자를 미리 정의된 index로 변환해주는 converter
                      batch_size=1,
                      img_size=(100,32),
                      max_text_len=22,   # 필터링을 위한 최대 글자 수
                      is_train=False,
                      character=''       # 학습대상으로 한정하기 위한 character
                ):
        
        self.label_converter = label_converter
        self.batch_size = batch_size
        self.img_size = img_size
        self.max_text_len = max_text_len
        self.character = character
        self.is_train = is_train
        self.divide_length = 100

        self.env = lmdb.open(dataset_path, max_readers=32, readonly=True, lock=False, readahead=False, meminit=False)
        with self.env.begin(write=False) as txn:
            num_samples = int(txn.get('num-samples'.encode()))
            self.num_samples = int(num_samples)
            self.index_list = [index + 1 for index in range(self.num_samples)]
        
    def __len__(self):
        if self.is_train:
            return math.ceil(self.num_samples/self.batch_size/self.divide_length)
        return math.ceil(self.num_samples/self.batch_size/self.divide_length)
    
    # index에 해당하는 image와 label을 가져오는 메소드
    def _get_img_label(self, index):
        with self.env.begin(write=False) as txn:
            label_key = 'label-%09d'.encode() % index
            label = txn.get(label_key).decode('utf-8')
            img_key = 'image-%09d'.encode() % index
            imgbuf = txn.get(img_key)

            buf = six.BytesIO()
            buf.write(imgbuf)
            buf.seek(0)
            try:
                img = Image.open(buf).convert('RGB')

            except IOError:
                img = Image.new('RGB', self.img_size)
                label = '-'
            width, height = img.size
            
            target_width = min(int(width*self.img_size[1]/height), self.img_size[0])
            target_img_size = (target_width,self.img_size[1] )
            img = np.array(img.resize(target_img_size)).transpose(1,0,2)
            label = label.upper()[:self.max_text_len]
            out_of_char = f'[^{self.character}]'
            label = re.sub(out_of_char, '', label)

        return (img, label)
    
    # idx번째 배치를 가져오는 메소드
    def __getitem__(self, idx):
        batch_indicies = self.index_list[
            idx*self.batch_size:
            (idx+1)*self.batch_size
        ]
        input_images = np.zeros([self.batch_size, *self.img_size, 3])
        labels = np.zeros([self.batch_size, self.max_text_len], dtype='int64')

        input_length = np.ones([self.batch_size], dtype='int64')*self.max_text_len
        label_length = np.ones([self.batch_size], dtype='int64')

        for i, index in enumerate(batch_indicies):
            img, label = self._get_img_label(index)
            encoded_label = self.label_converter.encode(label)
            width = img.shape[0]
            input_images[i,:width,:,:] = img
            if len(encoded_label) > self.max_text_len:
                continue
            labels[i,0:len(encoded_label)] = encoded_label
            label_length[i] = len(encoded_label)

        inputs = {
            'input_image': input_images,
            'label': labels,
            'input_length': input_length,
            'label_length': label_length,
        }
        outputs = {'ctc': np.zeros([self.batch_size, 1])}
        return inputs, outputs
        
    def on_epoch_end(self):
        self.index_list =  [index + 1 for index in range(self.num_samples)]
        if self.is_train :
            np.random.shuffle(self.index_list)
            return self.index_list

# %% [markdown]
# ### Encode

# %%
class LabelConverter(object):
    """ Convert between text-label and text-index """

    def __init__(self, character):
        self.character = "-" + character
        self.label_map = dict()
        for i, char in enumerate(self.character):
            self.label_map[char] = i

    def encode(self, text):
        encoded_label = []
        for i, char in enumerate(text):
            if i > 0 and char == text[i - 1]:
                encoded_label.append(0)    # 같은 문자 사이에 공백 문자 label을 삽입
            encoded_label.append(self.label_map[char])
        return np.array(encoded_label)

    def decode(self, encoded_label):
        target_characters = list(self.character)
        decoded_label = ""
        for encode in encoded_label:
            decoded_label += self.character[encode]
        return decoded_label

# %%
NUMBERS = "0123456789"
ENG_CHAR_UPPER = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
TARGET_CHARACTERS = ENG_CHAR_UPPER + NUMBERS
print(f"The total number of characters is {len(TARGET_CHARACTERS)}")
# Out:
# The total number of characters is 36

# %%
# 'HELLO'를 Encode한 후 Decode가 정상적으로 되는지 확인
label_converter = LabelConverter(TARGET_CHARACTERS)

encdoded_text = label_converter.encode('HELLO')
print("Encdoded_text: ", encdoded_text)
decoded_text = label_converter.decode(encdoded_text)
print("Decoded_text: ", decoded_text)
# Out:
# Encdoded_text:  [ 8  5 12  0 12 15]
# Decoded_text:  HEL-LO

# %% [markdown]
# ### Build CRNN model

# %%
def ctc_lambda_func(args): # CTC loss를 계산하기 위한 Lambda 함수
    labels, y_pred, label_length, input_length = args
    y_pred = y_pred[:, 2:, :]
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

# %%
def build_crnn_model(input_shape=(100,32,3), characters=TARGET_CHARACTERS):
    num_chars = len(characters)+2
    image_input = layers.Input(shape=input_shape, dtype='float32', name='input_image')

    # Build CRNN model
    conv = layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(image_input)
    conv = layers.MaxPooling2D(pool_size=(2, 2))(conv)
    conv = layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.MaxPooling2D(pool_size=(2, 2))(conv)
    conv = layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.MaxPooling2D(pool_size=(1, 2))(conv)
    conv = layers.Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.BatchNormalization()(conv)
    conv = layers.Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.BatchNormalization()(conv)
    conv = layers.MaxPooling2D(pool_size=(1, 2))(conv)     
    feature = layers.Conv2D(512, (2, 2), activation='relu', kernel_initializer='he_normal')(conv)
    sequnce = layers.Reshape(target_shape=(24, 512))(feature)
    sequnce = layers.Dense(64, activation='relu')(sequnce)
    sequnce = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(sequnce)
    sequnce = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(sequnce)
    y_pred = layers.Dense(num_chars, activation='softmax', name='output')(sequnce)

    labels = layers.Input(shape=[22], dtype='int64', name='label')
    input_length = layers.Input(shape=[1], dtype='int64', name='input_length')
    label_length = layers.Input(shape=[1], dtype='int64', name='label_length')
    loss_out = layers.Lambda(ctc_lambda_func, output_shape=(1,), name="ctc")(
        [labels, y_pred, label_length, input_length]
    )
    model_input = [image_input, labels, input_length, label_length]
    model = Model(
        inputs=model_input,
        outputs=loss_out
    )
    y_func = tf.keras.backend.function(image_input, [y_pred])
    return model, y_func

# %% [markdown]
# ### Train

# %%
train_set = MJDatasetSequence(TRAIN_DATA_PATH, label_converter, batch_size=BATCH_SIZE, character=TARGET_CHARACTERS, is_train=True)
val_set = MJDatasetSequence(VALID_DATA_PATH, label_converter, batch_size=BATCH_SIZE, character=TARGET_CHARACTERS)

checkpoint_path = HOME_DIR + '/model_checkpoint.hdf5'

model, y_func = build_crnn_model()
sgd = tf.keras.optimizers.Adadelta(lr=0.1, clipnorm=5)
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=sgd)
ckp = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path, monitor='val_loss',
    verbose=1, save_best_only=True, save_weights_only=True
)
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'
)
model.fit(train_set,
        steps_per_epoch=len(val_set),
        epochs=100,
        validation_data=val_set,
        validation_steps=len(val_set),
        callbacks=[ckp])
# Out:
# Epoch 1/100
# 63/63 [==============================] - 46s 410ms/step - loss: 33.2162 - val_loss: 27.0113
#
# Epoch 00001: val_loss improved from inf to 27.01126, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 2/100
# 63/63 [==============================] - 41s 640ms/step - loss: 26.6821 - val_loss: 26.1934
#
# Epoch 00002: val_loss improved from 27.01126 to 26.19341, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 3/100
# 63/63 [==============================] - 39s 609ms/step - loss: 25.9049 - val_loss: 25.9226
#
# Epoch 00003: val_loss improved from 26.19341 to 25.92261, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 4/100
# 63/63 [==============================] - 38s 594ms/step - loss: 25.8393 - val_loss: 29.1454
#
# Epoch 00004: val_loss did not improve from 25.92261
# Epoch 5/100
# 63/63 [==============================] - 37s 584ms/step - loss: 25.5331 - val_loss: 27.2271
#
# Epoch 00005: val_loss did not improve from 25.92261
# Epoch 6/100
# 63/63 [==============================] - 37s 578ms/step - loss: 25.1785 - val_loss: 25.1821
#
# Epoch 00006: val_loss improved from 25.92261 to 25.18209, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 7/100
# 63/63 [==============================] - 37s 579ms/step - loss: 24.7870 - val_loss: 25.9195
#
# Epoch 00007: val_loss did not improve from 25.18209
# Epoch 8/100
# 63/63 [==============================] - 35s 557ms/step - loss: 24.0978 - val_loss: 26.1652
#
# Epoch 00008: val_loss did not improve from 25.18209
# Epoch 9/100
# 63/63 [==============================] - 38s 604ms/step - loss: 23.2903 - val_loss: 23.3189
#
# Epoch 00009: val_loss improved from 25.18209 to 23.31892, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 10/100
# 63/63 [==============================] - 35s 555ms/step - loss: 22.4114 - val_loss: 22.3715
#
# Epoch 00010: val_loss improved from 23.31892 to 22.37155, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 11/100
# 63/63 [==============================] - 36s 568ms/step - loss: 21.1291 - val_loss: 20.9378
#
# Epoch 00011: val_loss improved from 22.37155 to 20.93784, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 12/100
# 63/63 [==============================] - 36s 570ms/step - loss: 19.1582 - val_loss: 22.7837
#
# Epoch 00012: val_loss did not improve from 20.93784
# Epoch 13/100
# 63/63 [==============================] - 36s 575ms/step - loss: 16.9419 - val_loss: 16.9342
#
# Epoch 00013: val_loss improved from 20.93784 to 16.93419, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 14/100
# 63/63 [==============================] - 36s 563ms/step - loss: 14.6990 - val_loss: 14.3389
#
# Epoch 00014: val_loss improved from 16.93419 to 14.33889, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 15/100
# 63/63 [==============================] - 36s 566ms/step - loss: 12.9179 - val_loss: 13.4634
#
# Epoch 00015: val_loss improved from 14.33889 to 13.46344, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 16/100
# 63/63 [==============================] - 37s 579ms/step - loss: 11.4178 - val_loss: 11.5038
#
# Epoch 00016: val_loss improved from 13.46344 to 11.50376, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 17/100
# 63/63 [==============================] - 37s 580ms/step - loss: 10.2976 - val_loss: 10.1496
#
# Epoch 00017: val_loss improved from 11.50376 to 10.14955, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 18/100
# 63/63 [==============================] - 36s 565ms/step - loss: 9.4014 - val_loss: 10.5671
#
# Epoch 00018: val_loss did not improve from 10.14955
# Epoch 19/100
# 63/63 [==============================] - 35s 558ms/step - loss: 8.7272 - val_loss: 8.6872
#
# Epoch 00019: val_loss improved from 10.14955 to 8.68715, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 20/100
# 63/63 [==============================] - 36s 568ms/step - loss: 8.2780 - val_loss: 9.5866
#
# Epoch 00020: val_loss did not improve from 8.68715
# Epoch 21/100
# 63/63 [==============================] - 35s 551ms/step - loss: 7.8801 - val_loss: 8.2226
#
# Epoch 00021: val_loss improved from 8.68715 to 8.22262, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 22/100
# 63/63 [==============================] - 37s 587ms/step - loss: 7.4809 - val_loss: 7.6917
#
# Epoch 00022: val_loss improved from 8.22262 to 7.69171, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 23/100
# 63/63 [==============================] - 36s 571ms/step - loss: 7.4180 - val_loss: 7.2998
#
# Epoch 00023: val_loss improved from 7.69171 to 7.29977, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 24/100
# 63/63 [==============================] - 38s 598ms/step - loss: 6.8528 - val_loss: 7.0611
#
# Epoch 00024: val_loss improved from 7.29977 to 7.06106, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 25/100
# 63/63 [==============================] - 36s 577ms/step - loss: 6.6144 - val_loss: 6.9282
#
# Epoch 00025: val_loss improved from 7.06106 to 6.92824, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 26/100
# 63/63 [==============================] - 37s 578ms/step - loss: 6.6683 - val_loss: 6.9232
#
# Epoch 00026: val_loss improved from 6.92824 to 6.92321, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 27/100
# 63/63 [==============================] - 37s 580ms/step - loss: 6.2964 - val_loss: 6.6386
#
# Epoch 00027: val_loss improved from 6.92321 to 6.63863, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 28/100
# 63/63 [==============================] - 38s 603ms/step - loss: 6.1095 - val_loss: 6.7646
#
# Epoch 00028: val_loss did not improve from 6.63863
# Epoch 29/100
# 63/63 [==============================] - 37s 586ms/step - loss: 5.7958 - val_loss: 6.0243
#
# Epoch 00029: val_loss improved from 6.63863 to 6.02426, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 30/100
# 63/63 [==============================] - 37s 580ms/step - loss: 5.7808 - val_loss: 5.8264
#
# Epoch 00030: val_loss improved from 6.02426 to 5.82644, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 31/100
# 63/63 [==============================] - 36s 560ms/step - loss: 5.5173 - val_loss: 5.7726
#
# Epoch 00031: val_loss improved from 5.82644 to 5.77261, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 32/100
# 63/63 [==============================] - 36s 563ms/step - loss: 5.5022 - val_loss: 5.6113
#
# Epoch 00032: val_loss improved from 5.77261 to 5.61126, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 33/100
# 63/63 [==============================] - 35s 558ms/step - loss: 5.3074 - val_loss: 5.6343
#
# Epoch 00033: val_loss did not improve from 5.61126
# Epoch 34/100
# 63/63 [==============================] - 35s 552ms/step - loss: 5.2844 - val_loss: 5.3715
#
# Epoch 00034: val_loss improved from 5.61126 to 5.37147, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 35/100
# 63/63 [==============================] - 37s 579ms/step - loss: 5.0129 - val_loss: 5.4545
#
# Epoch 00035: val_loss did not improve from 5.37147
# Epoch 36/100
# 63/63 [==============================] - 37s 584ms/step - loss: 4.9692 - val_loss: 5.2041
#
# Epoch 00036: val_loss improved from 5.37147 to 5.20413, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 37/100
# 63/63 [==============================] - 37s 584ms/step - loss: 5.0206 - val_loss: 5.1655
#
# Epoch 00037: val_loss improved from 5.20413 to 5.16555, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 38/100
# 63/63 [==============================] - 38s 603ms/step - loss: 5.0086 - val_loss: 5.0346
#
# Epoch 00038: val_loss improved from 5.16555 to 5.03458, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 39/100
# 63/63 [==============================] - 40s 633ms/step - loss: 5.1128 - val_loss: 4.8349
#
# Epoch 00039: val_loss improved from 5.03458 to 4.83493, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 40/100
# 63/63 [==============================] - 37s 581ms/step - loss: 4.8244 - val_loss: 4.9872
#
# Epoch 00040: val_loss did not improve from 4.83493
# Epoch 41/100
# 63/63 [==============================] - 36s 563ms/step - loss: 4.5699 - val_loss: 4.9034
#
# Epoch 00041: val_loss did not improve from 4.83493
# Epoch 42/100
# 63/63 [==============================] - 36s 576ms/step - loss: 4.4731 - val_loss: 4.8282
#
# Epoch 00042: val_loss improved from 4.83493 to 4.82821, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 43/100
# 63/63 [==============================] - 35s 559ms/step - loss: 4.4784 - val_loss: 4.6072
#
# Epoch 00043: val_loss improved from 4.82821 to 4.60725, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 44/100
# 63/63 [==============================] - 35s 557ms/step - loss: 4.4598 - val_loss: 4.5459
#
# Epoch 00044: val_loss improved from 4.60725 to 4.54585, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 45/100
# 63/63 [==============================] - 35s 556ms/step - loss: 4.4326 - val_loss: 4.4574
#
# Epoch 00045: val_loss improved from 4.54585 to 4.45737, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 46/100
# 63/63 [==============================] - 36s 572ms/step - loss: 4.2276 - val_loss: 4.6241
#
# Epoch 00046: val_loss did not improve from 4.45737
# Epoch 47/100
# 63/63 [==============================] - 37s 587ms/step - loss: 4.3744 - val_loss: 4.4369
#
# Epoch 00047: val_loss improved from 4.45737 to 4.43688, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 48/100
# 63/63 [==============================] - 34s 538ms/step - loss: 4.2182 - val_loss: 4.3488
#
# Epoch 00048: val_loss improved from 4.43688 to 4.34882, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 49/100
# 63/63 [==============================] - 35s 545ms/step - loss: 4.1338 - val_loss: 4.1763
#
# Epoch 00049: val_loss improved from 4.34882 to 4.17628, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 50/100
# 63/63 [==============================] - 37s 590ms/step - loss: 4.0165 - val_loss: 4.2446
#
# Epoch 00050: val_loss did not improve from 4.17628
# Epoch 51/100
# 63/63 [==============================] - 34s 532ms/step - loss: 3.9362 - val_loss: 4.1209
#
# Epoch 00051: val_loss improved from 4.17628 to 4.12093, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 52/100
# 63/63 [==============================] - 35s 553ms/step - loss: 4.0358 - val_loss: 4.4063
#
# Epoch 00052: val_loss did not improve from 4.12093
# Epoch 53/100
# 63/63 [==============================] - 34s 541ms/step - loss: 3.9849 - val_loss: 4.3130
#
# Epoch 00053: val_loss did not improve from 4.12093
# Epoch 54/100
# 63/63 [==============================] - 35s 550ms/step - loss: 4.0096 - val_loss: 3.9931
#
# Epoch 00054: val_loss improved from 4.12093 to 3.99307, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 55/100
# 63/63 [==============================] - 34s 528ms/step - loss: 3.7793 - val_loss: 4.0707
#
# Epoch 00055: val_loss did not improve from 3.99307
# Epoch 56/100
# 63/63 [==============================] - 34s 531ms/step - loss: 4.0466 - val_loss: 4.0488
#
# Epoch 00056: val_loss did not improve from 3.99307
# Epoch 57/100
# 63/63 [==============================] - 34s 530ms/step - loss: 3.7425 - val_loss: 3.9780
#
# Epoch 00057: val_loss improved from 3.99307 to 3.97804, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 58/100
# 63/63 [==============================] - 35s 559ms/step - loss: 3.8337 - val_loss: 3.9578
#
# Epoch 00058: val_loss improved from 3.97804 to 3.95783, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 59/100
# 63/63 [==============================] - 34s 538ms/step - loss: 3.6411 - val_loss: 3.9968
#
# Epoch 00059: val_loss did not improve from 3.95783
# Epoch 60/100
# 63/63 [==============================] - 33s 522ms/step - loss: 3.7491 - val_loss: 3.9954
#
# Epoch 00060: val_loss did not improve from 3.95783
# Epoch 61/100
# 63/63 [==============================] - 36s 572ms/step - loss: 3.5734 - val_loss: 3.9055
#
# Epoch 00061: val_loss improved from 3.95783 to 3.90550, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 62/100
# 63/63 [==============================] - 35s 551ms/step - loss: 3.7018 - val_loss: 3.6516
#
# Epoch 00062: val_loss improved from 3.90550 to 3.65159, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 63/100
# 63/63 [==============================] - 35s 546ms/step - loss: 3.4924 - val_loss: 3.6612
#
# Epoch 00063: val_loss did not improve from 3.65159
# Epoch 64/100
# 63/63 [==============================] - 34s 541ms/step - loss: 3.6383 - val_loss: 3.7104
#
# Epoch 00064: val_loss did not improve from 3.65159
# Epoch 65/100
# 63/63 [==============================] - 35s 549ms/step - loss: 3.5515 - val_loss: 3.6930
#
# Epoch 00065: val_loss did not improve from 3.65159
# Epoch 66/100
# 63/63 [==============================] - 34s 540ms/step - loss: 3.2928 - val_loss: 3.5326
#
# Epoch 00066: val_loss improved from 3.65159 to 3.53256, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 67/100
# 63/63 [==============================] - 35s 548ms/step - loss: 3.4302 - val_loss: 3.4964
#
# Epoch 00067: val_loss improved from 3.53256 to 3.49643, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 68/100
# 63/63 [==============================] - 35s 551ms/step - loss: 3.3267 - val_loss: 3.5386
#
# Epoch 00068: val_loss did not improve from 3.49643
# Epoch 69/100
# 63/63 [==============================] - 35s 553ms/step - loss: 3.3209 - val_loss: 3.6166
#
# Epoch 00069: val_loss did not improve from 3.49643
# Epoch 70/100
# 63/63 [==============================] - 34s 535ms/step - loss: 3.4773 - val_loss: 3.4717
#
# Epoch 00070: val_loss improved from 3.49643 to 3.47166, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 71/100
# 63/63 [==============================] - 35s 553ms/step - loss: 3.1797 - val_loss: 3.4401
#
# Epoch 00071: val_loss improved from 3.47166 to 3.44007, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 72/100
# 63/63 [==============================] - 38s 606ms/step - loss: 3.2881 - val_loss: 3.6385
#
# Epoch 00072: val_loss did not improve from 3.44007
# Epoch 73/100
# 63/63 [==============================] - 35s 554ms/step - loss: 3.3178 - val_loss: 3.3830
#
# Epoch 00073: val_loss improved from 3.44007 to 3.38297, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 74/100
# 63/63 [==============================] - 36s 565ms/step - loss: 3.3029 - val_loss: 3.3817
#
# Epoch 00074: val_loss improved from 3.38297 to 3.38173, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 75/100
# 63/63 [==============================] - 36s 561ms/step - loss: 3.3268 - val_loss: 3.4429
#
# Epoch 00075: val_loss did not improve from 3.38173
# Epoch 76/100
# 63/63 [==============================] - 35s 561ms/step - loss: 3.1651 - val_loss: 3.3886
#
# Epoch 00076: val_loss did not improve from 3.38173
# Epoch 77/100
# 63/63 [==============================] - 36s 564ms/step - loss: 3.2692 - val_loss: 3.3144
#
# Epoch 00077: val_loss improved from 3.38173 to 3.31437, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 78/100
# 63/63 [==============================] - 35s 554ms/step - loss: 3.0733 - val_loss: 3.3000
#
# Epoch 00078: val_loss improved from 3.31437 to 3.30005, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 79/100
# 63/63 [==============================] - 36s 561ms/step - loss: 3.2058 - val_loss: 3.3371
#
# Epoch 00079: val_loss did not improve from 3.30005
# Epoch 80/100
# 63/63 [==============================] - 35s 548ms/step - loss: 3.0407 - val_loss: 3.2618
#
# Epoch 00080: val_loss improved from 3.30005 to 3.26182, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 81/100
# 63/63 [==============================] - 35s 548ms/step - loss: 3.1286 - val_loss: 3.2422
#
# Epoch 00081: val_loss improved from 3.26182 to 3.24223, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 82/100
# 63/63 [==============================] - 35s 549ms/step - loss: 3.1510 - val_loss: 3.2554
#
# Epoch 00082: val_loss did not improve from 3.24223
# Epoch 83/100
# 63/63 [==============================] - 37s 587ms/step - loss: 2.9594 - val_loss: 3.2719
#
# Epoch 00083: val_loss did not improve from 3.24223
# Epoch 84/100
# 63/63 [==============================] - 36s 565ms/step - loss: 3.1947 - val_loss: 3.2129
#
# Epoch 00084: val_loss improved from 3.24223 to 3.21285, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 85/100
# 63/63 [==============================] - 36s 570ms/step - loss: 2.9509 - val_loss: 3.1185
#
# Epoch 00085: val_loss improved from 3.21285 to 3.11854, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 86/100
# 63/63 [==============================] - 34s 545ms/step - loss: 3.1584 - val_loss: 3.1466
#
# Epoch 00086: val_loss did not improve from 3.11854
# Epoch 87/100
# 63/63 [==============================] - 33s 522ms/step - loss: 3.0198 - val_loss: 3.1254
#
# Epoch 00087: val_loss did not improve from 3.11854
# Epoch 88/100
# 63/63 [==============================] - 33s 528ms/step - loss: 3.1331 - val_loss: 3.1078
#
# Epoch 00088: val_loss improved from 3.11854 to 3.10781, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 89/100
# 63/63 [==============================] - 35s 555ms/step - loss: 2.8511 - val_loss: 3.0379
#
# Epoch 00089: val_loss improved from 3.10781 to 3.03791, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 90/100
# 63/63 [==============================] - 34s 534ms/step - loss: 2.9836 - val_loss: 3.0396
#
# Epoch 00090: val_loss did not improve from 3.03791
# Epoch 91/100
# 63/63 [==============================] - 36s 561ms/step - loss: 3.1077 - val_loss: 3.1309
#
# Epoch 00091: val_loss did not improve from 3.03791
# Epoch 92/100
# 63/63 [==============================] - 36s 569ms/step - loss: 2.9007 - val_loss: 3.1292
#
# Epoch 00092: val_loss did not improve from 3.03791
# Epoch 93/100
# 63/63 [==============================] - 36s 569ms/step - loss: 2.7926 - val_loss: 3.1557
#
# Epoch 00093: val_loss did not improve from 3.03791
# Epoch 94/100
# 63/63 [==============================] - 36s 568ms/step - loss: 3.0132 - val_loss: 3.1361
#
# Epoch 00094: val_loss did not improve from 3.03791
# Epoch 95/100
# 63/63 [==============================] - 34s 531ms/step - loss: 3.0079 - val_loss: 3.0345
#
# Epoch 00095: val_loss improved from 3.03791 to 3.03449, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 96/100
# 63/63 [==============================] - 34s 545ms/step - loss: 2.7945 - val_loss: 2.9915
#
# Epoch 00096: val_loss improved from 3.03449 to 2.99147, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 97/100
# 63/63 [==============================] - 33s 519ms/step - loss: 3.0185 - val_loss: 2.9152
#
# Epoch 00097: val_loss improved from 2.99147 to 2.91521, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5
# Epoch 98/100
# 63/63 [==============================] - 34s 532ms/step - loss: 2.8674 - val_loss: 2.9413
#
# Epoch 00098: val_loss did not improve from 2.91521
# Epoch 99/100
# 63/63 [==============================] - 33s 519ms/step - loss: 2.6383 - val_loss: 2.9688
#
# Epoch 00099: val_loss did not improve from 2.91521
# Epoch 100/100
# 63/63 [==============================] - 32s 504ms/step - loss: 2.8820 - val_loss: 2.8846
#
# Epoch 00100: val_loss improved from 2.91521 to 2.88463, saving model to /aiffel/aiffel/cv/g12/model_checkpoint.hdf5

# %%
from IPython.display import display

test_set = MJDatasetSequence(TEST_DATA_PATH, label_converter, batch_size=BATCH_SIZE, character=TARGET_CHARACTERS)

model, y_func = build_crnn_model()

checkpoint_path = HOME_DIR + '/model_checkpoint.hdf5'
model.load_weights(checkpoint_path)
input_data = model.get_layer('input_image').output
y_pred = model.get_layer('output').output
model_pred = Model(inputs=input_data, outputs=y_pred)

def decode_predict_ctc(out, chars = TARGET_CHARACTERS, top_paths = 1):
    results = []
    beam_width = 5
    if beam_width < top_paths:
        beam_width = top_paths
    for i in range(top_paths):
        indexes = K.get_value(
            K.ctc_decode(
                out, input_length = np.ones(out.shape[0]) * out.shape[1],
                greedy =False , beam_width = beam_width, top_paths = top_paths
            )[0][i]
        )[0]
        text = ""
        for index in indexes:
            text += chars[index]
        results.append(text)
    return results

def check_inference(model, dataset, index = 5):
    for i in range(index):
        inputs, outputs = dataset[i]
        img = dataset[i][0]['input_image'][0:1,:,:,:]
        output = model_pred.predict(img)
        result = decode_predict_ctc(output, chars="-"+TARGET_CHARACTERS)[0].replace('-','')
        print("Result: \t", result)
        display(Image.fromarray(img[0].transpose(1,0,2).astype(np.uint8)))

check_inference(model, test_set, index=10)
# Out:
# Result: 	 SLINKING9999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F964C5C9F90>
# Result: 	 ALEPPO99999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F964B890D50>
# Result: 	 RWAMDA999999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F964C438C10>
# Result: 	 NATHANS99999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F964033D390>
# Result: 	 HALO99999999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F96402F7A90>
# Result: 	 HURLS9999999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F96403138D0>
# Result: 	 DOWNSIZE9999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F96402EF890>
# Result: 	 ROBOTIC99999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F9640264850>
# Result: 	 SLOPPY99999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F9640282F50>
# Result: 	 HERMITE99999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F96402FD990>

# %% [markdown]
# ### End-to-End OCR

# %%
import cv2
import matplotlib.pyplot as plt
from keras_ocr.detection import Detector

SAMPLE_IMG_PATH = HOME_DIR + '/data/sample.jpg'

detector = Detector()
# Out:
# Looking for /aiffel/.keras-ocr/craft_mlt_25k.h5

# %%
def detect_text(img_path):
    img = cv2.imread(img_path)
    line_img = img.copy()
    input_img = img[tf.newaxis,...]
    result = detector.detect(input_img)
    ocr_result = result[0]
    
    cropped_imgs = []
    for text_result in ocr_result:
        for i in range(4):
            if i==3:
                line_img = cv2.line(line_img,tuple(text_result[3]),tuple(text_result[0]),(0,0,255),10)
            else:
                line_img = cv2.line(line_img,tuple(text_result[i]),tuple(text_result[i+1]),(0,0,255),10)
        
        x_min = text_result[:,0].min() - 5
        x_max = text_result[:,0].max() + 5
        y_min = text_result[:,1].min() - 5
        y_max = text_result[:,1].max() + 5
        cropped_imgs.append(img[int(y_min):int(y_max),int(x_min):int(x_max)])
    
    return line_img, cropped_imgs

# %%
def recognize_img(input_img, input_img_size=(100,32)):
    # 잘려진 단어 이미지를 인식하는 코드
    img = input_img[:,:,::-1]
    img = cv2.resize(img, input_img_size)
    result_img = img.copy()
    img = img.transpose(1,0,2)
    img = img[tf.newaxis,...]
    output = model_pred.predict(img)
    result = decode_predict_ctc(output, chars="-"+TARGET_CHARACTERS)[0].replace('-','')
    print("Result: \t", result)
    display(Image.fromarray(img[0].transpose(1,0,2).astype(np.uint8)))

# %%
img, cropped_img = detect_text(SAMPLE_IMG_PATH)
plt.imshow(img[:,:,::-1])
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f9394545440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
for _img in cropped_img:
    recognize_img(_img)
# Out:
# Result: 	 UIRUL999999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F93945C5410>
# Result: 	 SLEEPER9999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F939428FF10>

# %% [markdown]
# ---

# %%
img, cropped_img = detect_text(SAMPLE_IMG_PATH)
plt.imshow(img[:,:,::-1])
# Out:
# WARNING:tensorflow:5 out of the last 17 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f944c10b710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
for _img in cropped_img:
    recognize_img(_img)
# Out:
# Result: 	 SNONRY999999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F944C0F6850>

# %%
img, cropped_img = detect_text(SAMPLE_IMG_PATH)
plt.imshow(img[:,:,::-1])
# Out:
# WARNING:tensorflow:6 out of the last 19 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f939c40b5f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
for _img in cropped_img:
    recognize_img(_img)
# Out:
# Result: 	 SALWANLY9999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F939C09AED0>

# %%
img, cropped_img = detect_text(SAMPLE_IMG_PATH)
plt.imshow(img[:,:,::-1])
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f939c149170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
for _img in cropped_img:
    recognize_img(_img)
# Out:
# Result: 	 SMOND9999999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F93945EAB50>
# Result: 	 VECTORSTOCK9999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F9394599C90>
# Result: 	 VECTORSTOCK9999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F93945420D0>
# Result: 	 COMIESAOSS9999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F9394564C10>

# %% [markdown]
# ### 회고

# %% [markdown]
# - '9999999999999999999' 이런식으로 숫자 뜨는거 오류 해결을 못했다.
# - 샘플 첫글자들은 정확하게 인식했다.
# - 숫자는 인식하지 못한다.
